# %%
# read in HH income data by zip code, skip 1 row
# keep columns: zip code, HH mean income, HH median income
# extract numeric data from Geographic area name

# %%
import pandas as pd

# %%
# HH income data
HH_income_file_path = "/Users/mursil/workspace_neelam/Data_Projects_Personal/Real_Estate_Project/Household Income by Zip Code/ACSST5Y2021.S1901_2023-10-13T122844/ACSST5Y2021.S1901-Data.csv"

# # Read the csv file into DataFrame
HH_income = pd.read_csv(HH_income_file_path, skiprows=1)

# %%
HH_income.head()
# Out:
#         Geography  Geographic Area Name  Estimate!!Households!!Total  \
# 0  0500000US32003  Clark County, Nevada                       816296
# 1  860Z200US84034           ZCTA5 84034                           49
# 2  860Z200US89001           ZCTA5 89001                          510
# 3  860Z200US89002           ZCTA5 89002                        12737
# 4  860Z200US89003           ZCTA5 89003                          514
#
#    Margin of Error!!Households!!Total  \
# 0                                2377
# 1                                  30
# 2                                 128
# 3                                 641
# 4                                 191
#
#    Annotation of Margin of Error!!Households!!Total  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# ...

# %%
HH_income = HH_income.drop(0, axis=0)

# %%
HH_income.head()
# Out:
#         Geography Geographic Area Name  Estimate!!Households!!Total  \
# 1  860Z200US84034          ZCTA5 84034                           49
# 2  860Z200US89001          ZCTA5 89001                          510
# 3  860Z200US89002          ZCTA5 89002                        12737
# 4  860Z200US89003          ZCTA5 89003                          514
# 5  860Z200US89004          ZCTA5 89004                          110
#
#    Margin of Error!!Households!!Total  \
# 1                                  30
# 2                                 128
# 3                                 641
# 4                                 191
# 5                                  57
#
#    Annotation of Margin of Error!!Households!!Total  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
# ...

# %%
# Remove "ZCTA5 " from the 'Geographic Area Name' column and convert the result to numeric
HH_income['Geographic Area Name'] = HH_income['Geographic Area Name'].str.replace('ZCTA5 ', '').astype(int)

# %%
HH_income.head()
# Out:
#         Geography  Geographic Area Name  Estimate!!Households!!Total  \
# 1  860Z200US84034                 84034                           49
# 2  860Z200US89001                 89001                          510
# 3  860Z200US89002                 89002                        12737
# 4  860Z200US89003                 89003                          514
# 5  860Z200US89004                 89004                          110
#
#    Margin of Error!!Households!!Total  \
# 1                                  30
# 2                                 128
# 3                                 641
# 4                                 191
# 5                                  57
#
#    Annotation of Margin of Error!!Households!!Total  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...

# %%
HH_income = HH_income.rename(columns={'Geographic Area Name': 'Zip_Code', 'Estimate!!Households!!Median income (dollars)' : 'Median_Income', 'Margin of Error!!Households!!Median income (dollars)' : 'Median_Income_Margin_of_Error',  'Estimate!!Households!!Mean income (dollars)' : 'Mean_Income', 'Margin of Error!!Households!!Mean income (dollars)' : 'Mean_Income_Margin_of_Error'})

# %%
HH_income.head()
# Out:
#         Geography  Zip_Code  Estimate!!Households!!Total  \
# 1  860Z200US84034     84034                           49
# 2  860Z200US89001     89001                          510
# 3  860Z200US89002     89002                        12737
# 4  860Z200US89003     89003                          514
# 5  860Z200US89004     89004                          110
#
#    Margin of Error!!Households!!Total  \
# 1                                  30
# 2                                 128
# 3                                 641
# 4                                 191
# 5                                  57
#
#    Annotation of Margin of Error!!Households!!Total  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#    Annotation of Estimate!!Households!!Total  \
# ...

# %%
HH_income = HH_income[['Zip_Code', 'Median_Income','Median_Income_Margin_of_Error', 'Mean_Income', 'Mean_Income_Margin_of_Error']]

# %%
HH_income.head()
# Out:
#    Zip_Code Median_Income Median_Income_Margin_of_Error Mean_Income  \
# 1     84034         53750                         39181       61392
# 2     89001         75612                         29846       86815
# 3     89002         88425                          5509      106159
# 4     89003             -                            **       44169
# 5     89004         66328                         20632       78475
#
#   Mean_Income_Margin_of_Error
# 1                       27023
# 2                       24185
# 3                        5227
# 4                       17697
# 5                       23136

# %%
HH_income.to_csv("HH_income.csv", index = False)
